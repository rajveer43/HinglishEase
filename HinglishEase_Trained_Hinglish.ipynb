# %%
import pandas as pd
import re
import tensorflow as tf
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np
import nltk.translate.bleu_score as bleu
import random
import string
from sklearn.model_selection import train_test_split
import os
import time

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
eng_hin = pd.read_csv(
    "/content/drive/MyDrive/PRL/task/data/synthetic-dataset/train.csv"
)
eng_hin.head()
# Out:
#                                              English  \
# 0  Program module is a file that contains instruc...
# 1  And to Thamud We sent their brother Sali 'h. H...
# 2              and, when reminded, do not remember\n
# 3                      you won the TED Prize 2011.\n
# 4  He gone to Kerodemal College of Delhi Universi...
#
#                                                Hindi  \
# 0  माड्यूल, एक संचिका होती है, जिसमें या तो स्रोत...
# 1  और (हमने) क़ौमे समूद के पास उनके भाई सालेह को ...
# 2  और जब उन्हें याद दिलाया जाता है, तो वे याद नही...
# 3          तुम्हें २०११ का टेड प्राइज़ मिल गया है.\n
# 4  उन्होंने बाद अध्ययन करने के लिए ये दिल्ली विश्...
#
#                                             Hinglish  Average rating  \
# 0  module , ek program hoti hai , jismen ya to so...               7
# 1  aur hamne aume samood ke pas unke bhaee saleh ...               6
# 2  aur jab unhen yad dilaya jata hai , to ve yad ...              10
# 3            tumhen २०११ ka ted prize mil gaya hai\n               9
# 4  unhonne bad science karne ke lie ye delhi univ...               7
#
#    Disagreement
# 0             6
# 1             4
# 2             0
# 3             1
# 4             0

# %%
# create a new dataframe of english and hinglish column
df = pd.DataFrame()
df["english"] = eng_hin["English"]
df["hindi"] = eng_hin["Hindi"]
df.head()
# Out:
#                                              english  \
# 0  Program module is a file that contains instruc...
# 1  And to Thamud We sent their brother Sali 'h. H...
# 2              and, when reminded, do not remember\n
# 3                      you won the TED Prize 2011.\n
# 4  He gone to Kerodemal College of Delhi Universi...
#
#                                                hindi
# 0  माड्यूल, एक संचिका होती है, जिसमें या तो स्रोत...
# 1  और (हमने) क़ौमे समूद के पास उनके भाई सालेह को ...
# 2  और जब उन्हें याद दिलाया जाता है, तो वे याद नही...
# 3          तुम्हें २०११ का टेड प्राइज़ मिल गया है.\n
# 4  उन्होंने बाद अध्ययन करने के लिए ये दिल्ली विश्...

# %%
eng_hin.dropna(inplace=True)
eng_hin.shape
# Out:
# (2766, 7)

# %%
import pickle

with open(
    "/content/drive/MyDrive/PRL/task/data/human-generated-dataset/train_human_generated.pkl",
    "rb",
) as f:
    human_generated = pickle.load(f)
    print("Human generated dataset size:", len(human_generated))

human_generated
# Out:
# Human generated dataset size: 1800
# {'Program module is a file that contains instructions which are either in the form of source code or machine language.\n': ['Program module ek sanchika hoti hai, jisme ya to source code ya machine language ke rup me anudesh nihit hote hai.\n',
#   'Program module ek sanchika hoti hai, that contains instructions which are either in the form of source code or machine language.\n',
#   'Program module is a file jisme source code or machine language ke rup me instructions nihit hote he.\n',
#   'Program module ak file hoti he that contains instructions which are either in source code or machine language. \n'],
#  "And to Thamud We sent their brother Sali 'h. He said:' My people! Serve Allah; you have no god other than Him. He brought you into being out of the earth, and has made you dwell in it. So ask Him to forgive you, and do turn towards Him in repentance. Indeed My Lord is near, responsive to prayers.\n": ['Aur humne unke bhai Salih ko Thamud ke paas bheja. Usne kaha, “My people! Serve Allah; you have no god other than him. Usne tumhe iss prithvi par laaya hai, and he has made you dwell in it. So ask him to forgive you and do turn towards Him in repentance. Indeed My Lord is near, responsive to prayers.\n',
#   'Aur humne unke bhai Salih ko Thamud ke paas bheja. He said, “My people! Serve Allah; uske alawa koi tumhara maabood nahi. He brought you into being out of the earth aur tumhe usme basaya hai. Usse kaho tumhe maaf kar de,  and do turn towards Him in repentance. Indeed My Lord is near, responsive to prayers.\n',
#   'We sent their brother sali to Thamud. He said: Meri kom, Allah hi ki parsatish karo no god other than him. Usi ne tumko earthe se paida kiya and has made you dwell in it. So ask him forgive you and do turn towards him in repentance. Aur sabki sunta he or prayers ko kabul karta he.\n',
#   'Aur humne Thamud ke pas unke brother sali’h ko bheja to He said,’My people! Serve Allah; You have no god other than him. He brought you into being out of the earth and has made you dwell in it. To usse magfirat ki dua mago fir uski bargah me tauba karo. Indeed My Lord is near, responsive to prayers.\n'],
#  'and, when reminded, do not remember\n': ['And jab remind karaya jaata hai, then they don’t remember.\n',
#   'Aur when yaad karaya jaata hai, toh ve remember nhi rakhte.\n'],
#  'you won the TED Prize 2011.\n': ['tumhe TED Prize 2011 mil gaya hai.\n',
#   'You won 2011 ka TED Prize.\n'],
#  'He gone to Kerodemal College of Delhi University, where he taken Science Graduate Degree.\n': ['Unhone baad adhyayan karne ke liye ye Delhi University ke Kerodemal College chale gae, where he taken science Graduate Degree.\n',
#   'He gone to Kerodemal College of Delhi University, Jaha inhone Vignaan snatak ki upadhi prapt ki.\n'],
#  'Then We awakened them to know which of the two groups could better calculate the length of their stay.\n': ['Fir humne unhe bheja to know which of the two groups could better calculate the length of their stay.\n',
#   'Then We awakened them taki malum kre ki dono groups me se kisne could better calculate the length of their stay.\n'],
#  'Really move all photos and videos to the trash?\n': ['kya aap really trash mai saare photo aur videos khiskaana chahte hai?\n',
#   'vakaai mai move all photos and videos to the trash?\n'],
#  'Excavations made in Malabar have proved the existence of chambers in which massive earthenware urns had been kept.\n': ['Excavations made in Malabar have proved the existence of kamre jinme bade bade bartan mile hai, jinme shav rakhe jate the.\n',
#   'Malabar mai excavations ke chambers mai rakhe hue bade bade earthenware urns mile hai, jinme shav rakhe jate the.\n',
#   'Malabar mein excavation se kamro mein rkhe hue bade bade bartan mile h\n',
#   'Excavations in malabar se kamro mein rakhe hue massive earthenware urns mile h\n'],
#  'And leave them desolate waste.\n': ['And ek samtal chatiyal maidaan banakar leave them\n',
#   'Aur desolate waste banakar chhodenge\n'],
#  "Please let me see when you 're online. Thanks!\n": ['Please let me see jab aap online ho. Dhanyavad.\n',
#   "Muje dekhne ke liye when you 're online. Thanks!\n"],
#  'A guidance and a mercy for the well - doers:\n': ['jo (well-doers) unn logo ke liye guidance va mercy hai.\n',
#   'jo (well-doers) unn logo ke liye guidance va rahmat hai.\n',
#   'hidayat and rahmat for the well - doers.\n'],
#  'In France, the news of one deed spreads like a flash and brings some pride to a disillusioned people.\n': ['In france, kaarname ki news flash ki tarah spread hoti hai aur disillusioned people garv mehsoos karte hai.\n',
#   'France mein ek deed ki khabar bijli ki tarah fail jaati hai and log bhram se mukt hokar pride mehsoos kar sakte hai.\n'],
#  'refuse him / her the permission to see your presence\n': ['Aapki presence ko dekhne ki permission na de.\n',
#   'Aapki upasthiti ko dekhne ki permission unhe refuse kare.\n',
#   'AApki presence ko dekhne ke liye refuse him the permission.\n',
#   'To see your presence unhe anumati de.\n'],
#  'Disable the new tab page menu for accessing tabs on other devices.\n': ['anya devices par tabs par pahuchne ke liye new tab page menu disable kare.\n',
#   'anya devices par tabs par pahuchne ke liye, disable the new tab page menu.\n'],
#  'Far from securing the ends of justice their pendency or disposal on merits will indubitably defeat the ends of justice.\n': ['Far from securing the ends of justice their pendency or disposal on merits, sunischit rup se nyay ke udeshyo ko vifal kar dega.\n',
#   'Justice ke udeshyo ki prapti se koso dur, unka aniryan ya yogyata ke adhar par niptaan will indubitably defeat the ends of justice.\n'],
#  'It is He who prevails over His creatures, and He is all - wise and aware.\n': ['It is he who is tatvadarshi, khabar rakhne wala and apne creatures par prevail karne waala.\n',
#   'Usne apne bando par purna adhikaar hai and he is all wise and aware.\n'],
#  'It belongs to the seventh century if not earlier , and was perhaps intended originally for the Buddhist creed , but was adopted later for a Vishnu temple , the principal deity being a recumbent Vishnu , or Anantasayin .\n': ['yadi yah pehle ka nahi, to bhi It belongs to the seventh century aur shayad originally Buddhist creed ke liye tha, but later vishnu temple mai rupaantarit kar diya gaya, jisme the principal diety being a recumbent Vishnu or Anantasayin .\n',
#   'if not earlier, to bhi it belongs to the seventh century, and was perhaps intended originally for the Buddhist creed , kintu baad mai vishnu temple mai rupaantarit kar diya gaya, the principal deity being a recumbent Vishnu , or Anantasayin .\n',
#   'Yadi yeh aur pehle ka nahi, to bhi 7th century ka bana ha aur perhaps mul roop se buddh creed ke liye tha, but later vishnu mandir mein ropantrit kr diya gaya jisme principle deity lete hue vishnu ya antshayi h\n',
#   'It belongs to satvi sadi, aur mul roop se was intended for boudh mat, kintu baad mein vishnu mandir ke liye adopt kiya gaya tha, pramukh devta jisme was a recumbent vishnu, or anantasayin \n'],
#  'We created you, then why do you believe not?\n': ['We created you,then tum sach kyun nahi mante ho?\n',
#   'Humne tumhe paida kiya hai, fir why do you believe not?\n',
#   'Hum created tumhe, fir tum believe kyu nahi kar rahe ho?\n'],
#  'You be there at 10 A. M. sharp.\n': ['aap sharp 10 A.M. baje wahan ho.\n',
#   'You be there at 10 A.M. tej.\n',
#   'aap praat 10 baje wahan ho sharp.\n'],
#  'Some months ago there were normal democratic elections there and as a result a popular radical party a joint popular front came into power .\n': ['Some months ago there were normal democratic elections there and aur falswarup vaha ak lokpriya redical party- samyukta lokpriya morcha satta me aayi.\n',
#   'Kuch months hue vaha samanya loktantrik elections hue and as a result a popular radical party a joint popular front came into power .\n'],
#  'Continue applying patches with resolved conflicts\n': ['with resolved conflicts jaari rakhe laagu kar raha he.\n',
#   'Continue applying patches ke sath parspar virodh.\n'],
#  'An organism or individual having a diploid set of chromosomes derived from each parent.\n': ['Koi avyav ya jiv having a diploid set of chromosomes derived from each parent.\n',
#   'An organism or individual jis me maata aur pita in dono se hi prapt gunsutra ka ek dohra gut he.\n'],
#  'And We sent down out of heaven water in measure and lodged it in the earth; and We are able to take it away.\n': ['And We sent down out of heaven water in measure and lodged it in the earth; Aur hum to yakinan uske gayab kar dene par bhi kabu rakhte he.\n',
#   'Aur humne aasman se ek andaje ke sath paani barsaya fir usko jamin me thahrae rakha, and we are able to take it away.\n'],
#  'The whole realm of satire, humour, or fantasy is open to the puppet producer.\n': ['The whole realm of vyagya, parihass, or kalpana is open to the puppet producer.\n',
#   'puppet producer ke samaksh satire, humour, or fantasy ka sansaar khula pada hai.\n'],
#  'But the physical love is only a bridge to cross over to the other bank葉he Annihilation of self.\n': ['But the physical love dusre tat-aatma-hanan-par pahuchne kaa setu maatra he.\n',
#   'Par Sharirik Prem is only a bridge to cross over to the other bank葉he Annihilation of self.\n'],
#  'His mother was darning a torn sock over a wooden mushroom.\n': ['Uski ma was darning a fata moza over a wooden mushroom.\n',
#   'His mother was darning a torn sock lakdi se bne kukurmute par.\n'],
#  'Every soul shall have a taste of death: And only on the Day of Judgment shall you be paid your full recompense. Only he who is saved far from the Fire and admitted to the Garden will have attained the object (of Life): For the life of this world is but goods and chattels of deception.\n': ['Every soul shall have a taste of death: And only on the Day of Judgment shall you be paid your full recompense. Jise aag se hatakar jannat me dakhil kr diya gaya, vah safal raha. Raha sansarik jivan, to vah maya-samagri ke siva kuchh bhi nahi.\n',
#   'Pratyek jiv mrutyu ka maja chakhnevaala he, aur tumhe to kiyamat ke din pura-pura badla de diya jayega. Only he who is saved far from the Fire and admitted to the Garden will have attained the object (of Life): For the life of this world is but goods and chattels of deception.\n'],
#  'Fluctuations in the production of raw jute, low yield, cost inflation, labour unrest, uncertain demand and obsolete machinery are some of its major problems.\n': ['Fluctuations in the production of raw jute, low yield, cost inflation, labour unrest, anischit mang, purani machinery kuch iski major samsyaye he.\n',
#   'Kachche jute ke production me utar-chadhav, kam paidavar, lagat sfiti, shram ashantosh, uncertain demand and obsolete machinery are some of its major problems.\n'],
#  'a lot of young people with a demographic dividend\n': ['With a demographic dividend kae yuva log.\n',
#   'Ek jansankhyikiy labhansh ke sath a lot of young people.\n'],
#  'If you believe you can, you probably can.\n': ['If you believe you can, to sambhavat aap kar sakte he.\n',
#   'Yadi aap yah mante he ki aap kar sakte he, yoy probably can.\n'],
#  'into a school. Everybody is wearing jeans, everybody is the same.\n': ['into a school. har koi jeans pehen raha hai, everybody is the same.\n',
#   'Ek school mai. Everybody jeans pehen rahe hai, everybody same hai.\n',
#   'Ek school mai. Everybody is wearing jeans, har koi same hai.\n',
#   'into a school. Everybody jeans pehen rahe hai, everybody same hai.\n',
#   'into a school. Everybody jeans pehen rahe hai, everybody is the same.\n',
#   'ek school mai. Everybody is wearing jeans, everybody same hai.\n'],
#  'Later a public meeting was called which was addressed by Hakim Ajmal Khan and Pandit Malaviya.\n': ['Pichhe ak badi meeting hui which was addressed by Hakim Ajmal Khan and Pandit Malaviya.\n',
#   'Later a public meeting was called jisse Hakim Ajmal Khan aur Pandit Malaviya ke bhasan hue.\n'],
#  'The highest amount of money that is required to be paid.\n': ['The highest amount of money jo mulya rup me di jani ho.\n',
#   'Adhik se adhik rashi that is required to be paid.\n'],
#  'These were the ushnisa or turban, a pair of flywhisks, umbrella, sword, sandals, and the royal standard.\n': ['yeh the; turban, chawaro ki jodi, umbrella, swords,chappal tatha rajashi thath baath se rahna.\n',
#   'These were the ushnisa or turban, chawaro ki jodi, chhatri, khadag, chappal and the royal standard.\n'],
#  'And remember Our servants Ibrahim and Ishaq and Yaqoub, men of power and insight.\n': ['Aur remember our servants Ibrahim and Ishaq and Yaqoob, jo power and insight wale the\n',
#   'And humare bando me Ibrahim aur Ishaq aur yaqoob ko remember karo, men of kuwat and basirat\n',
#   'And remember humare bando me Ibrahim and Ishaq and Yaqoob, jo kuwat and insight wale the\n'],
#  'Place the ten of spades next to the nine of spades.\n': ['Place the ten of spades next hukum ke nahla ko.\n',
#   'Hukum ke ten ke bagal me place the nine of spades.\n'],
#  '(Charles Tilly),Terror, Terrorism, Terrorist Sociological Theory (2004)22,5-13 (online)\n': ['(Charles Tilly),Terror, Terrorism, aatankvaadi samajshashtru sidhdhant (2004)22,5-13 (online)\n',
#   'Charles Tilly, aatank, aatankvaad, Terrorist Sociological Theory (2004)22,5-13 (online)\n'],
#  'Backup Evolution data and settings to an archive file\n': ['Backup Evolution data and settings, fir bhandaarit kre.\n',
#   'Evolution data aur settings ka backup le, to archive file.\n',
#   'Evolution data and settings ka backup le fir archive kare.\n',
#   'Backup evolution data and settings fir archive file kre.\n'],
#  'They distribute agricultural machinery; undertake wholesale, retail and foreign trade.\n': ['Yah krushi yantro, wholesale tatha retail avam foreign trade ko distribute and undertake karta he.\n',
#   'They distribute and undertake agriculture machinery, thok tatha khudra bajar avam foreign trade karta he.\n'],
#  'literature fo various dialects of hindi are still popular today, and even today, many poets and writers use regional languages for their work\n': ['Hindi ka literature of various dialects aaj bhi popular today, and even today, many poets and writers use regional languages for their work\n',
#   'Hindi ka literature of various dialects aaj bhi popular today, and even today, anek kavi aur lekhak apne work ke liye regional languages use karte hai.\n',
#   'Hindi ki various boliyon ka literature aaj bhi popular he even aaj bhi many poets and writers use regional languages for their work.\n',
#   'Literature for various dialects of hindi are still popular today and for their work aaj bhi anek poets and writers apni regional languages ka use karte he \n'],
#  'Rotate the image 90 degrees to the right\n': ['Chhavi ko ghumaye 90m degree to the right.\n',
#   'Rotate the image 90 degree dahine par.\n'],
#  "Moreover , even if we resolved the dispute by circumscribing its scope to some particular field of human endeavour and did agree on what is ' excellence ' , there is no knowing that it would be passed on to children .\n": ["Moreover , even if we resolved the dispute by circumscribing its scope to some particular field of human endeavour and what is ' excellence ' tab bhi aanevali pidhi ki santano me yah gun dekhai dega, is baat ki kpi guarantee nahi di ja sakti.\n",
#   'Aur kisi vishishta kshetra ke sandarbh excellence ka aarth kya hoga, is baat ka nirnay hum logo ne kar bhi liya tab bhi, there is no knowing that it would be passed on to children .\n'],
#  '” Tonight, it will be a year … ”\n': ['Tonight pura ek year ho jaaega.\n',
#   'Aaj raat it will a year.\n'],
#  'such as projections and judgements of others... yes.\n': ['Ha, jaise ke dusro ke baare me projections aur ray.\n',
#   'Yes, such as mansik kalpnaye and judgements of others.\n'],
#  'American Lung Association of New England on quality of air\n': ['American lung association of new england on vayu ki gudhvatha.\n',
#   'New england ki american lung association on quality of air.\n'],
#  'He cannot bring down its greater spiritual nature into this lower triplicity; for here the mental being is the highest expression of the Self.\n': ['Vah uski greater spiritual nature ko niche utarkar is lower triplicity me nahi laa sakta; kyuki yaha to mental being hi aatma ka highest expression hai.\n',
#   'Vah uski mahattar aadhyatmik prakruti ko niche utaarkar iss lower triplicity me nahi laa sakta because here the mental being is the highest expression of the Self.\n',
#   'He cannot bring down its greater spiritual nature into this lower triplicity kyonki yaha to manomay purush hi aatma ki highest abhivyakti he.\n',
#   'Vah uski greater spiritual nature ko niche utarkar is lower triplicity me nahi la sakta kyonki here the mental being is the highest expression of the self. \n'],
#  'by 5, so 1 times 5 is 5.\n': ['By 5 toh ek guna 5 barabar hai 5 ke.\n',
#   'Toh 1 guna 5 is 5.\n'],
#  'Candytuft is mostly cultivated for ornamental purposes.\n': ['Candytuft mostly ornamental uddeshyon ke liye ugaye jaate hai.\n',
#   'Candytuft is mostly cultivated for sajavati purposes.\n'],
#  'On the other hand, art flourished under Buddhist patronage.\n': ['Dusri aur, kala flourised under buddhist patronage.\n',
#   'On the other hand, buddhas ke sanrakshan mein art samridhshali bana.\n'],
#  'Standard Chartered has brought in 140 million.\n': ['140 million standard chartered laya hai.\n'],
#  'During the war years, the railways were under great strain, not only because of the growing needs of transportation of troops and war materials internally, but also because of the responsibility thrown on them to meet the demands of staff and material for the railways in the African theatre of war.\n': ['During the war years, the railways were under great strain, not only because of the growing needs of transportation of troops and war materials internally,varan Africi yuddha me railway ke liye staff aur samagri ki badhati hue mang ko pura karne ke un par saupe gaye dayitva ke karan tha.\n',
#   'Yuddh ke varso ke dauran, Railway par atyadhk dabaav tha. Yah na keval sena aur yuddha samagri ko dekh me hi laane le jaane karan tha,but also because of the responsibility thrown on them to meet the demands of staff and material for the railways in the African theatre of war.\n'],
#  'They said, ‘O Moses! Will you throw first, or shall we? ’\n': ['They said ,”ae Musa ! Will u throw first, ya fir pehle hum fekte hain?”\n',
#   'Ve bole,”O Moses! Ya toh tum feko pehle,or shall we?”\n',
#   'They said,”O Moses! Ya toh tum feko ya fir hum pehle fekte hain?”\n',
#   'Ve bole,”ae Musa!Will you throw pehle ya fir hum fekte hain.\n'],
#  'No maintenance charges required to be paid.\n': ['No required to be paid Koi anurakshan shulka.\n',
#   'Maintenance charges dene ki jarurat nahi he.\n'],
#  'Cannot attach CMS Enveloped data\n': ['CMS Enveloped data sanlagna nahi kar sakta he.\n',
#   'CMS lifafakrut ankada cannot attach.\n'],
#  'A culture of prevention rather than a culture of reaction is required in the mining industry as a value-driven commitment towards zero tolerance to such incidents.\n': ['Aisi dughatnaao ko bilkul sahan na karne ki mulya prerit pratibadhhta ke rup me, khanan industry me reaction ke culture ke bajaaye, prevention ke culture ki aavashyakta.\n',
#   'A culture of prevention bajay a culture of reaction ki mining industry me aesi incidents ko bilkul tolerance na  karne ki as a value driven commitment ke rup me aavshyakta he. \n',
#   'A culture of pevention rather than a culture of reaction aesi mulya prerit commitment ke rup me aese incidents ko telerance na krna required in the mining industry.\n'],
#  'It tells you what vitamin K deficiency bleeding is, discusses the benefits of vitamin K supplements and possible disadvantages of its use, and gives the best current advice.\n': ['yah patrak batata hai ki vitamin K deficiency ki vajah se khoon bahane lagana kya hai, discusses the benefits of vitamin K supplements and possible disadvantages of its use, and gives the best current jaankaari.\n',
#   'It tells you what vitamin K deficiency bleeding is, bhaash yah Vitamin K supplements ke benefits aur possible pratikul paristitiyon ke baare mai bhi jaankaari deta hai.\n'],
#  'In truth, when its desires are fulfilled, it returns to its own place and enjoys the happiness that is the Self.\n': ['In truth, when its desires are fulfilled, it returns to its own place aur aanand ka, aatma ka upyog karta he.\n',
#   'Vastutah jab uski ichchhaye puri ho jati he to vah apne sthan par vaapas aa jata he and enjoys the happiness that is the Self.\n'],
#  'Corporal punishment should be banished from schools and students should be encouraged to take positive initiatives.\n': ['Corporal punishment par schools mein rok lagani chahiye and students ko positive initiatives ke liye protsahit karna chahiye.\n',
#   'Schools should banish sharirik dand aur  vidhyarthis should be protsahit for rachnatmak pehel.\n'],
#  'Move% s onto% s.\n': ['%s move kare %s par.\n', 'kishkaaye %s onto %s.\n'],
#  "Let's see, let's do minus 5 / 7 divided by 10 / 3.\n": ['Lets see, nakaratmak 5/7 vibhajit hai 10/3 se.\n',
#   'Dekhe, lets do nakaratmak 5/7 divided by 10/3.\n',
#   'Lets see, minus 5/7 vibhajit hai 10/3 se.\n'],
#  "Is it possible for everyone to know one 's true nature?\n": ['Is it possible har koi apne sacche swaroop ko jaan sake?\n',
#   'Kya har koi apne true nature ko jaan sakte hai?\n',
#   'Is it possible to know one’s saccha swaroop?\n',
#   'Is it possible for everyone apna sachcha swaroop janna?\n',
#   'Kya har koi apne true nature ko jaan sakta hai?\n',
#   'Kya ye mumkin hai apna sahi sachcha swaroop janna?\n'],
#  "Don 't get pulled into that rush... into that storm.\n": ["Us bhid me Don 't get pulled … into that storm.\n",
#   'Into that Rush khinche nahi chale jana he… us toofan me.\n'],
#  'Import HandyShopper store names only as item tags.\n': ['As item tags only import HandyShopper store names.\n',
#   'Import Handyshopper store names only item tag ke roop me hi.\n'],
#  'In tha Law there are a number of bylaws under one law.\n': ['In the law, niyam ke antargat kai bylaws hote hai.\n',
#   'vidhi mai there are a number of upniyam hote hai.\n'],
#  'In the Gardens of delight (Paradise).\n': ['Nemat bhari Paradise me honge.\n',
#   'In jannato ki delight.\n'],
#  "Among the principal 'infant' industries of this period mention must be made of sugar, paper, and matches.\n": ['Chhote chhote infant industries of this period mukhr-oonshchhsh-ya shishu udhyogo me mention must made be of sugar, paper, and matches\n',
#   'Among the principal shishu udhyog is period ki charcha ki ja sakti hai chini, kagaz, aur diyaasalar ki.\n'],
#  'Last week , transporters in Delhi were up in arms against him , and , on April 10 , the first fir alleging a case of cheating and detailing his role in the CNG kit scam , was lodged at a Delhi police station .\n': ['Last week , transporters in Delhi were up in arms against him , and , on April 10 , the first fir alleging a case of cheating and detailing his role in the CNG kit scam, prathmiki darj karvaae.\n',
#   'Delhi ke transportes ne akjut ho April 10 ko unke against cheating ke aarop ke sath CNG kit scam me unki bhumikaa bataate was lodged at a Delhi police station .\n'],
#  'So, a smaller group, whether it is called a steering committee or something else, is needed which can be more active and can meet more frequently and with less expenses.\n': ['So, a smaller group, whether it is called a steering committee or something else, is needed Jo saal me kae baar mil sake, adhik sakriya ho sake aur kam kharch se kaam chala sake.\n',
#   'Isliye ek jyada chhote group ki jarurat he, chahe use aap karya sanchalan samiti kahe ya kuch aur which can be more active and can meet more frequently and with less expenses.\n'],
#  "They felt there wasn 't enough progress\n": ['They felt ki vaha paryapta pragati nahi thi.\n',
#   'Inhone mahsus kiya ki there wasn’t enough progress.\n'],
#  "he method of recording of votes by Members on `Ayes' and `Noes' slips is generally resorted to in the eventuality of :\n": ["the method of recording of votes by Members on `Ayes' and `Noes' slips samanyataya nimnalikhit paristhitio me apnaya jata he: \n",
#   '‘Han’ ya ‘Nahi’ parchiyo par sadasyo ke mato ka abhilekhan ka tarika is generally resorted to in the eventuality of :\n'],
#  'This is an account of (the fate of) the towns which We relate to you; of them are some that stand and (others) mown down.\n': ['This is an account of (the fate of) the towns which We relate to you; unme se baaz to us vakt tak kayam he aur baaz ka tahas nahas ho gaya.\n',
#   'Ae rasul ye chand bastiyo ke halat he jo  hum tum se bayan karte he; of them are some that stand and (others) mown down.\n'],
#  'Purchase of machinery and implements / equipment\n': ['Machinery evam upkarano ki kharidi.\n',
#   'Machinery evam upkarano ka purchase.\n',
#   'Machino avam equipment ki purchase.\n',
#   'Machinery and implements/equipment ki Kharid.\n'],
#  'Then it goes back to potential energy again.\n': ['To yah fir se  vapas to potential energy chala jata he \n',
#   'Then it goes back sambhavit energy ko fir se.\n'],
#  'OPV can be given to children till 5 years of age.\n': ['bachcho ko OPV 5 varsh ki age tak diya ja sakta hai.\n',
#   'OPV can be given to bachcho till 5 varsh of aayu.\n',
#   'Bachcho ko 5 years of age tak OPV can be given.\n'],
#  'Usman Riaz: Yes, that was the first one. And then I -\n': ['Usman Riaz: Yes, that was the first one. aur phir mai -\n',
#   'Usman Riaz: Yes, yah pehla tha. And then I -\n'],
#  'Info to be shown for this item\n': ['Is mad ke liye Info to be shown.\n',
#   'For this item dikhaaye jaane ke liye jaankari.\n'],
#  "But during his father 's gall - bladder operation he admitted him to a paying bed at the Bangur Hospital.\n": ["But during his father 's gall - bladder operation, Bangur Hospital ke paying bed bharti kara kar.\n",
#   'Baap ke gaal-bladder ka operation karaya  he admitted him to a paying bed at the Bangur Hospital.\n'],
#  'Wind speed = %d kilometers/hour\n': ['hawa ke speed = %d kilometers/hour\n',
#   'Wind ki gati = %d kilometers/hour\n'],
#  'If selected, you will be notified when entering an SSL enabled site\n': ['If selected, you will be notified jab aap SSL saksham site par pravesh karte he.\n',
#   'Yadi chuna gaya he, when entering an SSL enabled site to aapko notified kiya jayega.\n'],
#  'Each vertex has a label, and these labels must have the following property.\n': ['Pratyek vertext ak label he, and these labels must have the following property.\n',
#   'Each vertex has a label, aur in label following gun hona aavshyak he.\n'],
#  '(ii) the Minister for Tuensang affairs shall deal with, and have direct access to the Governor on, all matters relating to the Tuensang district but he shall keep the Chief Minister informed about the same;\n': ['ii) the Minister for Tuensang affairs shall deal with, and unke sambandh me Governor ke pas  relating to the Tuensang district direct access hogi but he shall keep the Chief Minister informed about the same;\n',
#   '(ii) Tuensang affairs minister Tuensang district se relating sabhi vishayo ki babat karya krega aur unke sabandh me have direct access to the Governor,but he shall keep the Chief Minister informed about the same;\n'],
#  "He said, “O my son, do not relate your vision to your brothers, lest they plot and scheme against you. Satan is man 's sworn enemy.\n": ['He said, “O my son, do not relate your vision to your brothers, lest they plot and scheme against you. Satan aadmi ka khulaa dushman he.\n',
#   "Yaakub ne kaha ae beta kahi apnaa khvaab apne brothers se na dohraana varna vah log tumhare liye makkari ki tabdir karne lagenge isme to sak nahi he ki, Satan is man 's sworn enemy.\n"],
#  'The day the sky will tremble,\n': ['Jis din aasmaan chakkar khane lagega,\n',
#   'The day aasmaan will tremble,\n',
#   'jis day sky chakkar khane lagega,\n',
#   'jis day aasmaan will tremble,\n'],
#  'Joint Forest Management Committees have played a key role in curbing the exploitation of forest resources that had often led to the marginalization and deprivation of tribal people.\n': ['Samyukta van prabandhan committes ne van sansadhano ke dohan ko rokne me mahatvapurna bhumika  nibhai he that had often led to the marginalization and deprivation of tribal people.\n',
#   'Joint Forest Management Committees have played a key role in curbing the exploitation of forest resources aksar janjaatiy logo ko pichadaa aur abhavgrasta banane vaale he.\n'],
#  'A skilled or artistic worker or craftsman.\n': ['A skilled or artistic worker ya karigar.\n',
#   'Koi kushal ya kalatmak majdoor ya craftsman.\n'],
#  'I know that the Bodhisattva lovingly regards all living creatures to deliver them from misery!\n': ['I know bodhisattva apne sabhi creatures par kripa bikhere hue hai.\n',
#   'Mai jaanta hu bodhisattva lovingly regards all pratiyo to deliver them from misery.\n'],
#  '&Always Open Files of This Type\n': ['&Always open iss prakar ki fiiles.\n',
#   'Is type ki file &hamesha khole.\n'],
#  "Greek 'ouranos' for 'heaven'. Named after the planet Uranus.\n": ["'swarg' ke liye Greek mai 'ouranos'. Uranus planet ke upar naam rakha gaya hai.\n",
#   "Greek mai 'ouranos' for 'swarg'. Named after the grah Uranus.\n",
#   "Greek 'ouranos' for 'heaven'. Uranus grah ke upar naam rakha gaya hai.\n"],
#  'All right, this is another one that should be cut and pasted.\n': ['All theek hai, this is another one jo kata aur chipkaya jaana chahiye.\n',
#   'Sab right hai, yeh ek aur ek cut aur paste kiya jaana chahiye.\n'],
#  '"(xviib)\tany compensation or other payment referred to in clause (xi) of sub-section (2) of section 56;";\n': ['Any pratikar or anya payment referred to khand(xi) of updhara(2) of section(56).\n',
#   'section 56 ki subsection (2) ke clause(xi) mein nirdisht any compensation ya koi sandaay.\n',
#   'Koi pratikaar ya other payment referred to in clause(xi) of updhara(2) of section 56.\n'],
#  "The Agreement on South Asian Free Trade Area (SAFTA) was signed by all the member States of the South Asian Association for Regional Cooperation (SAARC) during the twelfth 'SAARC Summit' held in Islamabad on 4 - 6th January, 2004.\n": ['all the member States of the South Asian Association for Regional Cooperation (SAARC) was signed Dakshini asia mukta karobar kshetra(safta) par kararname par islamabad me 4-6 january ko aayojit (saarc ke dauran0.\n',
#   "The Agreement on South Asian Free Trade Area (SAFTA) was the twelfth 'SAARC Summit' held in Islamabad on 4 - 6th January, 2004 Barrhaven Dakshin asiai kshetriya sahyog sangh sammelan ke dauran.\n"],
#  "The three saw a shepherd maid churning curd in front of her house and telling the children playing around her, 'Go away, you kids, lest the curd thumi droplet should spill upon you.\n": ['The three saw a shepherd maid churning curd in front of her house and telling the children playing around her,’ Bhag jao, bachcho, nahi to dahi ki bunde thumi tumhare upar uchhalkar girengi.\n',
#   "Un teeno ne ek gvalin ko dekha jo apne ghar ke samne curd math rahi thi aur apne charo taraf khelte hue children se kah rahi thi, 'Go away, you kids, lest the curd thumi droplet should spill upon you.\n"],
#  "Failed to unlock lock file '% s' '% s'\n": ['lock file ko unlock karne mai fail.\n',
#   "asafal to unlock lock file '% s' '% s' \n"],
#  'We have tried to correct them.\n': ['humne koshish ki hai to correct them.\n',
#   'We have tried unhe sudhaarne ki.\n'],
#  'Having nothing worthwhile to do, he organized a society of like - minded persons to divert his mind.\n': ['Having nothing worthwhile to do, usne like minded logon ki ek society bana li to divert his mind.\n',
#   'Kuch khaas kaam nhi hone ke kaaran, he diverted his dhyaan dusri aur in organising a society of apne jaise vichaar vaale logon ki.\n'],
#  'Through ‘e - FILING’ only Advocate - on Record’ and petitioners - in - person can file cases in the Supreme Court of India\n': ['E- filing ke madhyam se, Advocate on record aur petitioners in person Supreme court of India me case file kar sakte hai.\n',
#   'E- filing ke madhyam se, Advocate on record aur petitioners in person can file cases in the Supreme Court of India. \n',
#   'Through ‘e-filing’ only advocate on record and petitiones kevak pidit person supreme court me  mukadma file kar sakta he.\n',
#   'E- Filing ke through se supreme court of India me only pidit person arthatpetitioners- in-person can file the cases.\n'],
#  'We think doodling is something you do when you lose focus,\n': ['We think doodling karne vaale ka dhyan bhang ho chuka he.\n',
#   'AEsa mana jata he ki doodling is something you do when you lose focus,\n',
#   'This may be called the renaissance of North India.\n',
#   'इसे उत्तर भारत का पुनर्जागरण कहा जा सकता है। \n',
#   'This may be called  UttarBharat ka punrjagran.\n',
#   'Ise kaha ja sakta he The renaissance of North India.\n'],
#  'It assists the government in formulating and implementing policies for national development.\n': ['It assists for national government nitiyo ke nirman aur karyanvayan me sarkar ki.\n',
#   'Yah national development ke liye assists the government in formulating and implementing policies .\n'],
#  'Anaerobic is a technical word which literally means without oxygen.\n': ['Anaerobic ek technical word hai jiska shaabdik arth hai without oxygen.\n',
#   'Anaerobic ek technical word hai jiska shaabdik arth hai bina pranvayu ke.\n',
#   'Anaerobic is a tantrik shabd which literally means bina pranvayu ke.\n'],
#  "“ Well . . . so I can do things , ” he had responded . <s> “ And so I can change those things that I don ' t want to happen . ”\n": ['“ Well . . . so I can do things , ” he had responded , aur un cheezo ko badal saku jinhe mai ghatit hote hue nahi dekhna chahta.\n',
#   "“Isiliye ki mai kuchh kar saku,” usne kaha, “And so I can change those things that I don ' t want to happen . ”\n",
#   'isliye ki me kuch kar saku,” Unt chalak ne kaha,” And so I can change those things  jinhe me ghatit hote hue nahi dekh sakta.”\n',
#   "“ Well . . . so I can do things , ” he had responded . “ aur un things ko badal saku jinhe I don ' t want to happen . ”\n"],
#  'In his will Vitthal bhai patel named all his billions of property to Subash babu.\n': ['In his will Vitthal bhai patel named apni carore ki sampati Subhash babu ke.\n',
#   'Vitthal bhai patel ne apni vasiyat me named all his billions of property to Subash babu.\n'],
#  'He was born in the city of Surat in Gujarat on 24th August, 1833.\n': ['24th August, 1833 ko he was born in the city of Surat in Gujarat.\n'],
#  'A structure above the surface.\n': ['Above the surface samrachana.\n',
#   'Prushtha ya satah se upar A structure.\n'],
#  'and when the Koran is recited to them they do not bow?\n': ['and when the Koran is recited to them to sajde me nahi gir padte?\n',
#   'Aur jab unhe Koran padhakar sunaya jata he to they do not bow?\n'],
#  "We 're going to win because we have dreams.\n": ['Hum are going to win kyonki we have dreams\n',
#   'We are jeetne wale hai because we have sapne\n',
#   'Hum jeetne wale hai because hamare paas sapne hai \n',
#   'We are going to win kyonki hamare paas dreams hai\n'],
#  'Leave Me alone with he whom I created\n': ['Leave me alone with the one jise maine paida kiya.\n',
#   'The one whom I created, mujhe uske saath akela chhod do.\n',
#   'With he whom i created muje akela chood do.\n',
#   'Leave me alone with he jise mene create kiya.\n'],
#  'Mankind were one community, and Allah sent (unto them) prophets as bearers of good tidings and as warners, and revealed therewith the Scripture with the truth that it might judge between mankind concerning that wherein they differed. And only those unto whom (the Scripture) was given differed concerning it, after clear proofs had come unto them, through hatred one of another. And Allah by His Will guided those who believe unto the truth of that concerning which they differed. Allah guideth whom He will unto a straight path.\n': ['Mankind were one community, and Allah sent (unto them) prophets as bearers of good tidings and as warners, and revealed therewith the Scripture with the truth that it might judge between mankind concerning that wherein they differed. And only those unto whom (the Scripture) was given differed concerning it, after clear proofs had come unto them, through hatred one of another. And Allah by His Will guided those who believe unto the truth of that concerning which they differed. Khuda jis ko chahe rahe rast ki hidayat karta he.\n',
#   'Sab log ek hi din rakhte the, khuda ne najat se khush khabri dene vale aur ajab se darane vale pegambaro ko bheja, and revealed therewith the Scripture with the truth that it might judge between mankind concerning that wherein they differed. And only those unto whom (the Scripture) was given differed concerning it, after clear proofs had come unto them, through hatred one of another. And Allah by His Will guided those who believe unto the truth of that concerning which they differed. Allah guideth whom He will unto a straight path.\n'],
#  '“ But , above all , I learned that these things are all so simple that they could be written on the surface of an emerald . ”\n': ['”Magar is sabse zyada I learned that ye sab cheeze itni saral hai ki inhe emerald ki surface par likha ja sakta hai.”\n',
#   'Magar is sabse zyada maine yah seekha ki these things are all so simple that they could be written on the surface of an emerald . ”\n',
#   'Magar is sabse jyada i learned that things are all so simple ki inhe emerald ki satah par bhi likha ja sakta he.\n',
#   'But, above all, mene yah sikha ki ye these all things itni simple he ki they could be written on the surface of an emerald.\n'],
#  'A complaint was also made about the delay in the Industrial Relations Bill.\n': ['the delay in the Industrial Relations Bill ki bhi shikayat mili he.\n',
#   'A complaint was also made about Industrial sambandh vidheyak me deri.\n'],
#  'He is the Lord of the heavens and the earth and all that is between them. He is the Beneficent God and no one will be able to address Him.\n': ['He is the losrd of dharti and aakash and all that is between. Voh atyant beneficient hai and unko address karna unke bas ka nhi.\n',
#   'Vah heavens aur earth ka aur unke beech ka sab lord hai, he is very kripasheel and no one can address him.\n'],
#  'The region was endemic for malaria, Kala - a - zar and leprosy.\n': ['The kshetr was endemic for malaria, Kala-a-azar aur kushth rog.\n',
#   'Yah region malaria, kala-a-azar and leprosy se prabhavit hai.\n'],
#  'The whole of Rashtrapati Bhavan would be with them in their efforts to bring up their children.\n': ['Unke bachcho ki parvarish me the whole of Rashtrapati Bhavan would be with them\n',
#   'Poora Rashtrapati Bhavan unke sath hai in their efforts to bring up their children \n'],
#  '"\'And in the End He will return you into the (earth), and raise you forth (again at the Resurrection)?\n': ['"\'And in the End He will return you into the (earth),Aur (kayamat me usi se) nikaal kar khada karegaa.\n',
#   'Fir tumko usi me dobaara le aayega, and raise you forth (again at the Resurrection)?\n'],
#  'In 1882 , Lord Ripon established local self-government in India with the setting up of district local boards .\n': ['In 1882 , Lord Ripon established local self-government jilla sthaniy boards ke gathan ke sath india me sthapna ki.\n',
#   '1882 me Lord Ripon ne district local boards ke with setting up India me local self-government ki sthapana ki.\n'],
#  'Open the selected bookmark in a new tab\n': ['Chayanit pasand ko naye tab me open kare.\n',
#   'Selected bookmark ko naye tab me khole.\n',
#   'Selected chaynit ko open in a new tab.\n',
#   'Naye tab me Open the selected bookmark \n'],
#  'India participated, actively and constructively in the negotiations and sought to place the Treaty in a disarmament framework by proposing its linkage with a time - bound programme for the universal elimination of all nuclear weapons.\n': ['India participated, actively and constructively in the negotiations and duniya se samasta parmanu hathiyaro ki samapti ke liye ek samaybaddh karyakram ka prastav karke is sandhi ko nirastrikaran ke dhanche me dhalne ki mang jahir ki.\n',
#   'Bharat ne in charchao me sakriya aur rachanatmak dhang se hissa liya and sought to place the Treaty in a disarmament framework by proposing its linkage with a time - bound programme for the universal elimination of all nuclear weapons.\n'],
#  "A former Mujahideen commander , Haq 's ties with the CIA went back to the Soviet-Afghan war of the 1980s .\n": ["A former Mujahideen commander , Haq 's ties with the CIA went back 80 ke dashak ke Soviet-Afghan yuddha ke samay se.\n",
#   'A former Mujahideen commander ,the Soviet-Afghan war of the 1980s ke samay se hi CIA se jude the.\n'],
#  'In your provisions Allah has preferred some of you above others. But, those who have been preferred do not give their provisions to those whom their right hand possess so that they might be equal therein. What, do they vainly disbelieve the favor of Allah?\n': ['Aur allah hi ne tumame se baj ko baj par rijak tarjih di he fir jin logo ki roji jyada di gayi he vah log apni roji mese un logo ko jin par unka dardast he denevala nahi barar he to , do they vainly disbelieve the favor of Allah?\n',
#   'In your provisions Allah has preferred some of you above others. But, those who have been preferred do not give their provisions to those whom their right hand possess so that they might be equal therein. To kya ye log khulaki neamat ke liye munikar he.\n'],
#  "“It 's nice for swimming there. ”\n": ["“It 's nice there pani me tairne ka.”\n",
#   'Vaha bahut badhiya intajam he for swimming.\n'],
#  'In tapeworm infestation human are the primary host.\n': ['In tapeworm infestation manushya prathmik host hai.\n',
#   'Tapeworm infestation mai human primary poshi hai.\n',
#   'Tapeworm infestation mai manushya primary poshi hai.\n'],
#  'The Juvenile Justice Board apparently has given benefit to the appellant by treating his age to be 20 years as on 13. 08. 2003 which was on the lower side within the range of one year fixed by the Medical Board.\n': ['The juvenile justice board apparently has given benefit to the appealarthi by treating his aayu 20 varsh as on 13.08.2003 jo medical board dwara fixed one year ki seema ke lower side ki taraf hai.\n',
#   'Kishore nyaya board ne prakat roop se appellant ko 13.08.2003 par uski age 20 years maankar, which was on the bhitar side of the range fixed by the medical board, laabh diya hai.\n'],
#  'He said that their job is multifarious. He advised them to always remember that their conduct and behaviour is a reflection not only of the police force but is actually a projection of the entire administration before the common people.\n': ['He said that their job is multifarious.Unhone salaah di ki unhe always yaad rakhana chahiye ki unke vyavhaar aur aacharan se na keval police seva ke baare me najariya banata he, varna vah vaastav me aam janata ke samne pure prashashan ka pratibimb hota he.\n',
#   'Unhone kaha ki unka karya bahuaayami he. He advised them to always remember that their conduct and behaviour is a reflection not only of the police force but is actually a projection of the entire administration before the common people.\n'],
#  'Rural electrification (Ekal Electric House)\n': ['Rural vidyutikaran(Ekal Electric House)\n',
#   'Gramin electrification(Ekal Bijali Ghar)\n'],
#  'The Indian National Congress reacted sharply to the appointment of the Simon Commission .\n': ['The Indian National Congress reacted sharply Simon Commission ke gathan par.\n',
#   'Indian National Congress ne Simon Commision ke appointment par reacted sharply.\n'],
#  'Snow leopard hunts blue sheep in the Himalayas.\n': ['Him leopard Himalayas mai neeli bhed ka hunt karta hai.\n',
#   'Him tenduaa hunts neeli bhed in the Himalayas.\n',
#   'Snow leopard Himalayas mai blue sheep ka shikaar karta hai.\n'],
#  'Water resources development and management will have to be planned for a hydrological unit.\n': ['Water resources development and management will have to be planned ek hydrological ikai ke liye.\n',
#   'Jal sansadhan vikas aur prabandhan ki yojna banani hogi for a hydrological unit.\n'],
#  'The Madras High Court was a pioneer in the enrolment of women.\n': ['Madras High Court women ke enrolment mai bhi agreni raha hai.\n',
#   'Madras High Court women ke pravesh mai bhi agreni raha hai.\n',
#   'Madras uchch nyayalay was a pioneer in the enrolment of women.\n'],
#  'Malik Bhago, the chief of the place invites the Guru to partake food from the rich feast arranged by him.\n': ['Sthan mukhiya, Malik bhago Guruji ko invites to partake food from the rich feast arranged by him.\n',
#   'Malik Bhago, the chief of the place invites the Guru apne dvara arranged ki hue sandar davat me bhojan ke liye.\n'],
#  'We have not heard of any such thing in the old religion. This is nothing but a fabrication.\n': ['We have not heard of any such thing in the old religion. Na ho ye man gadhanta he.\n',
#   'Hum logo ne to ye baat pichhale din me kabhi suni bhi nahi.This is nothing but a fabrication.\n'],
#  'There is a lesson for you concerning cattle. We provide you with drink from their bellies and many other benefits. You can consume them as meat.\n': ['There is a lesson for you concerning cattle. unke bellies mai jo kuch hai usme se hum tumhe khilate hai. aur tumhare liye usme bahut-se benefits hai and You can consume them as meat.\n',
#   'aur nishchaya hi tumhare liye chopaayeeon mai bhi ek lesson hai. We provide you with drink from their bellies and many other benefits. aur tum unhe khaate bhi ho.\n',
#   'Aur nishchay hi chopayon mein bhi ek lesson h. Unke peto mein jo kuvh h usme se ham tumhe pilate h. And for you unme bohot se faide h aur unhe tu meat ki trha kha b skte ho\n',
#   'Tumhare liye there is a lesson concerning cattle. We provide you with drink from their bellies aur tumhare liye unme bohot se faide b h aur tum unhe khate b ho\n'],
#  'Ganesh Chaturthi and Janmashtmi are the other two festivals which are celebrated with lots of fun and frolic.\n': ['Inke alava Ganesh Chaturthi aur Janamashtmi  kuch adhik fun and frolic ke sang celebrate kiye jate hain.\n',
#   'Ganesh Chaturthi and Janamashtmi are the other two festivals jo dhoom dhaam ke sang manaye jate hain.\n'],
#  'Bharavi was almost a contemporary of Kalidasa.\n': ['Bharavi karib karib Kalidas ke contemporary the.\n',
#   'Bharavi was almost a samkaaleen of Kalidasa.\n'],
#  'Recognizing this mantra of statecraft, Karnataka pursues the deepening of bond between the government and the governed.\n': ['statecraft ke iss mantra ko pahchante hue, Karnataka pursues the deepening of bond between the government and the governed.\n',
#   'Recognizing this mantra of statecraft, karnataka dwara shaashan aur shaasiton ke bich bond ko deepen banane ka prayas kiya ja raha hai.\n',
#   'Recognizing this mantra of shashankala, karnatak pursues deepening of sambandh between shashan and shashit\n',
#   'Shashankala ke iss mantra ko recognize krte hue, karnataka dvara government and governed ke bich bond ko ghanisht banane ka prayas kiya jaa rha h\n'],
#  'The birth of Urdu itself is due to this fact.\n': ['The birth of Urdu itself iss shakti se hi paida hui hai.\n',
#   'Urdu bhi Hindi ki iss fact se hi birth hua hai.\n'],
#  'Disability and Housing Policy housingpolicy_disability@detr.gov.uk\n': ['Disability aur Rihaish ke baare me niti housingpolicy_disability@detr.gov.uk\n',
#   'Apang and Housing Policy housingpolicy_disability@detr.gov.uk\n'],
#  'Observe the fly land on the ceiling of your zoom after its flight.\n': ['Observe the fly after its flight apne kamne ki chat par bethte hue.\n',
#   'Gharelu makkhi ko Observe land on the ceiling of your zoom after its flight.\n'],
#  'Today, the Allahabad High Court has jurisdiction over the largest state in India, covering nearly one-sixth of our total population.\n': ['Today, the Allahabad High Court has jurisdiction over the largest state in India, Jisme hamari population ka lagbhag chhattha hissa shamil tha.\n'],
# ...
#   'Jab aap inn developing societies ke ilako mai jaate hai.\n'],
#  'Few, if any of us, can use this highest reason with any purity, but the attempt to do it is the topmost capacity of the inner instrument, the antahkarana.\n': ['Few, if any of us, can use this highest reason with any purity, to ve virle hi hote he, kintu iske liye prayatna karna antahkarna ki topmmost capacity he.\n'],
#  "This position is similar to royal position, just the woman to take the other side of your face is the face of men. In a way it 's back to enter the position. The man' s situation stays the same kind of right royal position, but women by men toward the back right in front of his penis is hard bringing up my cunt. Then slowly enter the penis cunt gives. Women in this position quite comfortable lives. It supported him get his feet that put him in the attack is easier. This position is changing dramatically because of it with some other ideas on other furniture can be pursued.\n": ["This position is similar to royal position, just the woman to take the other side of your face is the face of men. In a way it 's back to enter the position. The man' s situation stays the same kind of right royal position, but women by men toward the back right in front of his penis is hard bringing up my cunt. Then slowly enter the penis cunt gives.Is position me mahila kaafi aaramdayak sthiti me rahti he, isme use sahara uske pairo se milta he jisse use dhakke lagane me bhi asani hoti he. Yah position aaschryajanak rup se parivartanshil he isliye ise kuchh anya idea ke sath dusre furniture par bhi apnaai ja sakti he.\n",
#   'Yah position shahi position ki hi tarah he bas isme mahila apni chehara purush ke chehare ke dusri or kar leti he. Ek tarah se yah pichhe se pravesh ki bhi position he isme purush ki sthiti thik shahi position ki hi tarah rahti he lekin mahila purush ki or pith karke thik uske ling ke samne apni yoni ko laakar khadi hoti he fir dhire se yoni ko ling me pravesh karati he.Women in this position quite comfortable lives. It supported him get his feet that put him in the attack is easier. This position is changing dramatically because of it with some other ideas on other furniture can be pursued.\n'],
#  'You know, my work is inspired\n': ['You know,mera kam prabhavit he.\n',
#   'Aap jante he,my work is inspired.\n'],
#  'started speaking to us in the 20th century,\n': ['started baatchit to us in the 20th century,\n',
#   'started baatchit to us in the 20th sadi,\n',
#   'started speaking to us in the 20th sadi,\n',
#   'se hamari baatchit 20th century mai start hui,\n',
#   'se hamari baatchit 20th century mai shuru hui,\n'],
#  'Alas the woe that day for those who deny!\n': ['Tabahi he us din for those who deny!\n',
#   'Alas the woe that day juthlanevaalo ki!\n'],
#  'learned the correct initial state for the 17 - bit LFSR, we will have also\n': ['learned the correct initial state for the 17 - bit LFSR, hame bhi karna hoga.\n',
#   'Correct prarambhik rajya sikhaa 17- bit LFSR ke liye, We will have also.\n'],
#  'I ask no recompense of you; my reward is only with the Lord of the Universe.\n': ['I ask no recompense of you; Mera pratidaan to bas saare sansaar ke Lord ke jimme he.\n',
#   'Me is kaam par tumse koi pratidaan nahi mangata, my reward is only with the Lord of the Universe.\n'],
#  'Child - 3: Tell us now, Grandpa!\n': ['Child - 3: phir sunao, Grandpa!\n',
#   'Child - 3: Tell us now, dada!\n',
#   'bacha - 3: Tell us now, dada!\n',
#   'bacha - 3: phir sunao, Grandpa!\n'],
#  "O Prophet, say to your wives: 'If you seek this life and its finery, come, I will release you with a fine release.\n": ['O Prophet, say to your wives ki agar tum duniyaavi jindagi aur uski aaraish va jonat ki khvaha ho to udhar aao me tum logo ko kuchh sajo saman de du aur unvaane shaishta se rukhsat kar du.\n',
#   'Ae rasool apni bivio se kah do ki “ if you seek this life and its finery, come, I will release you with a fine release.\n'],
#  'His old friend Amar Singh helped him, when his company ABCL failed and he had to thereby face financial trouble.\n': ['Unke old friend ne Amar Singh ne when his company ABCL failed ho jane ke karan fincial trouble me help ki.\n',
#   'His old friend Amar Singh helped him, when his company ABCL failed ke karan aarthik trouble ke samay inki help ki.\n'],
#  '(b) where the marriage of his parents does not subsist, in the net wealth of that parent who maintains the minor child in the previous year as defined in section 3 of the Income-tax Act, and where any such assets are once included in the net wealth of either parent, any such assets shall not be included in the net wealth of the other parent in any succeeding year unless the Assessing Officer is satisfied, after giving that parent an opportunity of being heard, that it is necessary so to do ;\n': ['(b)Jaha uske parents ka vivah astitva me nahi he, in the net wealth of that parent who maintains the minor child in the previous year as defined aaykar adhiniyam ki dhara 3 me and where any such assets are once included in the net wealth of either parent, any such assets shall not be included in the net wealth of the other parent in any succeeding year unless the Assessing Officer is satisfied,Us parents ko sunvai ka avsar dene ke paschat, that it is necessary so to do ;\n',
#   '(b) where the marriage of his parents does not subsist, in the net wealth of that parent who maintains the minor child in the previous year as defined in section 3 of the Income-tax Act, aur jaha aesi koi aastiya parents me se kisi ak ke shuddha dhan me ak bar included kar li jati he, any such assets shall not be included in the net wealth of the other parent in any succeeding yearjab tak nirnadhar adhikari is  satisfied, after giving that parent an opportunity of being heard,aesa karna aavshyak he\n'],
#  'The beaters ran away after injuring the man.\n': ['pitne wale aadmi ko injure karke bhag gaye.\n',
#   'Aadmi ko ghayal karne ke baad, the beaters ran away.\n'],
#  'Then came forward Rajaraja Varma, diffident and nervous.\n': ['Them saamne aaye diffident and nervous rajaraja verma.\n',
#   'Iske baad came forward rajaraja verma, bhaybheet aur aashanka se bhare hue.\n'],
#  "There are those who disbelieve in Allah and His Messengers and seek to differentiate between Allah and His Messengers, and say: 'We believe in some and deny others, and seek to strike a way between the two.'\n": ['There are those who disbelieve in Allah and His Messengers and seek to differentiate between Allah and His Messengers, and say: Hum baaz par imaan laye he aur baaz ka inkar karte aur chahte he ki is ke darmiyan ak dusri rah nikle.\n',
#   "Beshak jo log Allah aur uske messengers se inkar karte he aur Allah aur uske rasoole me tafaraka dalna chahte he aur kahte he ki 'We believe in some and deny others, and seek to strike a way between the two.'.\n"],
#  'Speaking on the occasion, the President said India is fortunate to have a large young population to take forward her aspirational agenda of change.\n': ['Speaking on the occasion, the President said India is fortunate to have a large young population parivartan ki akanksha purna karya suchi ki prapti ke liye.\n',
#   'Is avasar par Rashtrapati ne kaha ki, Bharat saubhagyashali he ki uske pass vishal yuva pidhi he to take forward her aspirational agenda of change.\n'],
#  'But that brings me to lesson number two:\n': ['Is tarah me apne to lesson number two pahuchti hu.\n',
#   'But that brings me dusre sabak tak.\n'],
#  'Or like abundant rain from the cloud in which is utter darkness and thunder and lightning; they put their fingers into their ears because of the thunder peal, for fear of death, and Allah encompasses the unbelievers.\n': ['Or jaise abundant varsha from the cloud in which is utter andhera and garaj and lightning; they put their ungaliyan in their kaano me because of the bijli ki kadak for the bhay of mratyu and Allah encompasses the inkar karne  walo ko\n',
#   'Ya (unki misal aisi hai) like the akash se varsha ho rahi ho jiske sath utter darkness aur thunder aur chamak bhi ho; ve bijli ki kadak ke karan fear of death se apne kaano me ungaliyan de le rahe aur Allah ne to unbelievers ko gher rakha hai\n'],
#  'Presence of excess ammount of uric acid in the urine.\n': ['urine mai uric acid mai uplabdh excess ammount.\n',
#   'Presence of atyadhik matra of uric acid in the urine.\n',
#   'Mutra mein uric acid ka excess amount uplabdh\n',
#   'Uric acid ki atyadhik matra mutra mein present\n',
#   'Urine mein excess amount of uric acid uplabdh\n'],
#  'She was touted as the next dream girl.\n': ['She was touted as the agli dream girl\n',
#   'Mudda unhe next swapan sundari karar diya ja raha tha\n'],
#  'Indeed, We thus reward the doers of good.\n': ['Indeed we thus reward the uttamkaro.\n',
#   'Nissandeh hum does of good ko rewward karte hai.\n'],
#  'If this option is checked, every new view will display marks for code folding, if code folding is available.\n': ['If this option is checked, every new view will display marks for code folding, Yadi code folding uplabdh he.\n',
#   'Yadi yah vikalp chuna jaata he, har naya drashya code folding ke marks dikhayega, if code folding is available.\n'],
#  'We gave the four a row and we gave the eight a row.\n': ['We gave the four a row and 8 ko ek pankti dete he.\n',
#   'Ham 4 ko ek pankati dete he aur we gave the eight a row.\n'],
#  'and the smell of the earth, the wheat, the grass, the charged particles.\n': ['Aur mitti, gehu, ghas, the smell of earth, the charged particles.\n',
#   'And earth ki gandh,mitti,the wheat, the grass, the charged particles.\n'],
#  'The cyst got intumesce as it was not treated.\n': ['Ilaaj nhi hone ke kaaran cyst got intumesce.\n',
#   'As the cyst was not treated, woh suuj gya.\n'],
#  'Many scholars - and , of course , there are many who dispute the point - are of the opinion that quite possibly the idea of making a harp originated in the twang of the hunting or martial bow and the plectrum in the arrow .\n': ['Many scholars - and , of course , there are many who dispute the point - are of the opinion that quite possibly shikari ya yuddh smbandhi dhanush aur ban ke kon dwara utpann tankar se dimag me aya hoga.\n',
#   'Halaki anek vidhvan is mat ka virodh krte he, fir bhi bahut se vidhvano ki yah manyata he ki tantra-vadhya ke nirmarn ka vichar sambhavat the idea of making a harp originated in the twang of the hunting or martial bow and the plectrum in the arrow.\n'],
#  'In the year 1985-86, the erstwhile Ministry of Welfare was bifurcated into the Department of Women and Child Development and the Department of Welfare.\n': ['In the year 1985-86, purvarti kalyan mantralay was bifurcated into mahila aevam baal vikaas vibhaag and kalyan vibhaag.\n',
#   'Varsh 1985-86 mein erstwhile Ministry of Welfare ko department of women and child development aur department of welfare mein vibhaajit kiya gya tha.\n',
#   'In the year 1985-86,  purvarti kalyan mantralay ko department of women and child development aur department of welfare mein vibhajit kiya tha.\n',
#   'Varsh 1985-86 mein erstwhile Ministry of Welfare was bifurcated into mahila aevam baal vikaas vibhaag and kalyan vibhaag.\n',
#   'varsh 1985-86 me erstwhile ministry of welfare ko department of Women and children development and department of welfare me bifurcate kiya gaya tha.\n',
#   'In the year 1985-86, poorvavarti kalyan mantralay ko mahila aivam baal vikas vibhag and kalyan vibhag me bifurcate kiya.\n',
#   'In the year 1985-86, poorvavarti kalyan mantralay was bifurcated into mahila aivam baal vikas vibhag and kalyan vibhag me vibhakt kiya gaya tha.\n'],
#  "A pangolin 's territory is around 3 square miles 8 sq km.\n": ["A pangolin 's territory is around 8 varga kilometer ka hota he.\n",
#   'Pangolin ka kshetra is around 3 square miles 8 sq km.\n'],
#  'Till, when the Messengers despaired, deeming they were counted liars, Our help came to them and whosoever We willed was delivered. Our might will never be turned back from the people of the sinners.\n': ['Till, When the messengers despaired, un logo ne samaj liya ki vah juthlaye gaye Whosoever we willed was delivered to jise humne chaha najat di aur hamara ajab sinners people ke sar se to tala nahi jata.\n',
#   'Pahle ke messengers ne tablige risalat yaha tak ki jab paigamber despaired ho gaye aur deeming they were counted liars, our help came to them and unke pas hamari madad pahuchi. Our might will never be turned back from the people of the sinners.\n'],
#  'The Ministry of Labour &amp; Employment, Government of India, instituted the National Safety Awards (Mines) in 1983 for the contest year 1982 to promote a competitive spirit amongst mine operators for the betterment of safety standards in mines and to give due recognition to outstanding safety performance at the national level.\n': ['Ministry of Labour and Employment, Government of India, ne mines me safety standards ke betterment aur national level par outstanding safety performance ko recognition dene ke liye pratyogita varsh 1982 ke liye 1983 me National Safety Awards (Mines) ko institute kiya tha.\n',
#   'Mines me safety standards ke betterment aur national level par outstanding safety performance ko recognition dene ke liye the Ministry of Labour &amp; Employment, Government of India, instituted the National Safety Awards (Mines) in 1983 for the contest year 1982.\n',
#   'Government of India ke The ministry of labour  & amp; Employment  ne mine operator ki safety standard ke liye aur  competitive spirit ko promote karne ke liye national level par pratiyogita varsh 1983 me outstanding safety performance ka the National Safety Awards(Mines) ka aarambh kiya.\n',
#   'To promote a competitive spirit amongst mine operators for the betterment of safety standards in mines and to give due recognition to outstanding safety performance at the national level, bharat Sarkar ke Shram aur Rojgar Mantralay ne National Safety Awards(Mines) ka 1983 me contest year ke liye aarambh kiya. \n'],
#  'Dhanpat Rai Shreevastav, who wrote with pen name Premchand (31 July 1880 - 8 October 1936) was one of the greatest Indian , Hindi and Urdu writers.\n': ['Dhanpat Rai Shreevastav, who wrote with pen name Premchand (31 July 1880 - 8 October 1936), Hindi aur Urdu ke mahantam Indian lekhako me se ek he.\n',
#   'Premchand (31 july 1880-8 october 1936) ke upnaam se likhne vaale Dhanpat Rai Shreevastav was  one of the greatest Indian, Hindi and Urdu writers.\n'],
#  "In the twenty first century Maoist 's rebel spread a lot.\n": ['In the twenty first century Nepal me maoivaadio ka aandolan tez hota gaya.\n',
#   "Ikkisvi sadi ki suruaat me, Maoist 's rebel spread a lot.\n"],
#  'These poems lack the sombre grandeur of Prantik, for the memory of the Borderland and the haunting sense of the terror and beauty that Meanwhile he was content to relax and watch and savour what simple delight of sight and sound were still left for him on earth.\n': ['These poems lack the sombre grandeur of Prantik, for the memory of the Borderland and the haunting sense of the terror and beauty that is samay ve unke liye earth par bache simple delight of sight and sound ko dekhkar relax se aashvat ho rahe the aur unka aanand uthate prasann the.\n',
#   'In Poems sankalano me?Prantik?ki  sombre grandeur nahi thi. Kyonki ab bordarland ki memory ya santras aur beauty ka parivesh tham chala tha aur kavii ek bar fir dharti ki narm baho me tha.Meanwhile he was content to relax and watch and savour what simple delight of sight and sound were still left for him on earth.\n'],
#  'He said, “Our Lord is He who gave everything its existence, then guided it. ”\n': ['He said, "hamara Lord wah hai jisne har chiz ko uske(munashib) shurat ataa farmai."\n',
#   'Musha ne kaha "Our Lord is He jisne har chiz ko uske shurat ataa farmai"\n'],
#  'It was Senator Obama when they created it. They changed the name later.\n': ['It was Senator Obama when they created it. Bad me unhone name badal diya.\n',
#   'Jab unhone ise banaya to vah SEnator Obama tha. They changed the name later.\n'],
#  ...}

# %%
exclude = set(string.punctuation)  # Set of all special characters
remove_digits = str.maketrans("", "", string.digits)  # Set of all digits

# %%
def preprocess(text):
    """Function to preprocess English sentence"""
    text = text.lower()  # lower casing
    text = re.sub("'", "", text)  # remove the quotation marks if any
    text = "".join(ch for ch in text if ch not in exclude)
    text = text.translate(remove_digits)  # remove the digits
    text = text.strip()
    text = re.sub(" +", " ", text)  # remove extra spaces
    text = "<start> " + text + " <end>"
    return text

# %%
def preprocess_hin(text):
    """Function to preprocess Marathi sentence"""
    text = re.sub("'", "", text)  # remove the quotation marks if any
    text = "".join(ch for ch in text if ch not in exclude)
    text = re.sub("[२३०८१५७९४६]", "", text)  # remove the digits
    text = text.strip()
    text = re.sub(" +", " ", text)  # remove extra spaces
    text = "<start> " + text + " <end>"
    return text

# %%
eng_hin["english"] = df["english"].apply(preprocess)
eng_hin["hindi"] = df["hindi"].apply(preprocess_hin)

eng_hin.rename(columns={"english": "english", "hindi": "hindi"}, inplace=True)

eng_hin.head()
# Out:
#                                              English  \
# 0  Program module is a file that contains instruc...
# 1  And to Thamud We sent their brother Sali 'h. H...
# 2              and, when reminded, do not remember\n
# 3                      you won the TED Prize 2011.\n
# 4  He gone to Kerodemal College of Delhi Universi...
#
#                                                Hindi  \
# 0  माड्यूल, एक संचिका होती है, जिसमें या तो स्रोत...
# 1  और (हमने) क़ौमे समूद के पास उनके भाई सालेह को ...
# 2  और जब उन्हें याद दिलाया जाता है, तो वे याद नही...
# 3          तुम्हें २०११ का टेड प्राइज़ मिल गया है.\n
# 4  उन्होंने बाद अध्ययन करने के लिए ये दिल्ली विश्...
#
#                                             Hinglish  Average rating  \
# 0  module , ek program hoti hai , jismen ya to so...               7
# 1  aur hamne aume samood ke pas unke bhaee saleh ...               6
# 2  aur jab unhen yad dilaya jata hai , to ve yad ...              10
# 3            tumhen २०११ ka ted prize mil gaya hai\n               9
# 4  unhonne bad science karne ke lie ye delhi univ...               7
#
#    Disagreement                                            english  \
# 0             6  <start> program module is a file that contains...
# 1             4  <start> and to thamud we sent their brother sa...
# 2             0    <start> and when reminded do not remember <end>
# 3             1                <start> you won the ted prize <end>
# 4             0  <start> he gone to kerodemal college of delhi ...
#
#                                                hindi
# 0  <start> माड्यूल एक संचिका होती है जिसमें या तो...
# 1  <start> और हमने क़ौमे समूद के पास उनके भाई साल...
# 2  <start> और जब उन्हें याद दिलाया जाता है तो वे ...
# 3    <start> तुम्हें का टेड प्राइज़ मिल गया है <end>
# 4  <start> उन्होंने बाद अध्ययन करने के लिए ये दिल...

# %%
def tokenize(lang):
    lang_tokenizer = tf.keras.preprocessing.text.Tokenizer(filters="")
    lang_tokenizer.fit_on_texts(lang)

    tensor = lang_tokenizer.texts_to_sequences(lang)

    tensor = tf.keras.preprocessing.sequence.pad_sequences(
        tensor, padding="post", maxlen=20, dtype="int32"
    )

    return tensor, lang_tokenizer

# %%
def load_dataset():
    input_tensor, inp_lang_tokenizer = tokenize(eng_hin["english"].values)
    target_tensor, targ_lang_tokenizer = tokenize(eng_hin["hindi"].values)

    return input_tensor, target_tensor, inp_lang_tokenizer, targ_lang_tokenizer

# %%
input_tensor, target_tensor, inp_lang, targ_lang = load_dataset()

# %%
max_length_targ, max_length_inp = target_tensor.shape[1], input_tensor.shape[1]

# %%
(
    input_tensor_train,
    input_tensor_val,
    target_tensor_train,
    target_tensor_val,
) = train_test_split(input_tensor, target_tensor, test_size=0.2)

print(
    len(input_tensor_train),
    len(target_tensor_train),
    len(input_tensor_val),
    len(target_tensor_val),
)
# Out:
# 2212 2212 554 554

# %%
BUFFER_SIZE = len(input_tensor_train)
BATCH_SIZE = 32
N_BATCH = BUFFER_SIZE // BATCH_SIZE
embedding_dim = 256
units = 1024
steps_per_epoch = len(input_tensor_train) // BATCH_SIZE

vocab_inp_size = len(inp_lang.word_index.keys())
vocab_tar_size = len(targ_lang.word_index.keys())

dataset = tf.data.Dataset.from_tensor_slices(
    (input_tensor_train, target_tensor_train)
).shuffle(BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)

# %%
embeddings_index = dict()
f = open(
    "/content/drive/MyDrive/PRL/task/data/synthetic-dataset/glove.6B.300d.txt"
)
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype="float32")
    embeddings_index[word] = coefs
f.close()

embedding_matrix = np.zeros((vocab_inp_size + 1, 300))
for word, i in inp_lang.word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

# %%
class Encoder(tf.keras.Model):
    def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
        super(Encoder, self).__init__()
        self.batch_sz = batch_sz
        self.enc_units = enc_units
        self.embedding = tf.keras.layers.Embedding(
            input_dim=vocab_size,
            output_dim=embedding_dim,
            name="embedding_layer_encoder",
            trainable=False,
        )
        self.gru = tf.keras.layers.GRU(
            units,
            return_sequences=True,
            return_state=True,
            recurrent_activation="sigmoid",
            recurrent_initializer="glorot_uniform",
        )

    def call(self, x, hidden):
        x = self.embedding(x)
        output, state = self.gru(x, initial_state=hidden)
        return output, state

    def initialize_hidden_state(self):
        return tf.zeros((self.batch_sz, self.enc_units))

# %%
class Decoder(tf.keras.Model):
    def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
        super(Decoder, self).__init__()
        self.batch_sz = batch_sz
        self.dec_units = dec_units
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
        self.gru = tf.keras.layers.GRU(
            units,
            return_sequences=True,
            return_state=True,
            recurrent_activation="sigmoid",
            recurrent_initializer="glorot_uniform",
        )
        self.fc = tf.keras.layers.Dense(vocab_size)

        # used for attention
        self.W1 = tf.keras.layers.Dense(self.dec_units)
        self.W2 = tf.keras.layers.Dense(self.dec_units)
        self.V = tf.keras.layers.Dense(1)

    def call(self, x, hidden, enc_output):
        hidden_with_time_axis = tf.expand_dims(hidden, 1)

        score = self.V(
            tf.nn.tanh(self.W1(enc_output) + self.W2(hidden_with_time_axis))
        )

        attention_weights = tf.nn.softmax(score, axis=1)

        context_vector = attention_weights * enc_output
        context_vector = tf.reduce_sum(context_vector, axis=1)

        x = self.embedding(x)

        x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)

        output, state = self.gru(x)

        output = tf.reshape(output, (-1, output.shape[2]))

        x = self.fc(output)

        return x, state, attention_weights

    def initialize_hidden_state(self):
        return tf.zeros((self.batch_sz, self.dec_units))

# %%
tf.keras.backend.clear_session()

encoder = Encoder(vocab_inp_size + 1, 300, units, BATCH_SIZE)
decoder = Decoder(vocab_tar_size + 1, embedding_dim, units, BATCH_SIZE)

# %%
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction="none"
)


def loss_function(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)

    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask

    return tf.reduce_mean(loss_)

# %%
checkpoint_dir = "./training_checkpoints"
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(
    optimizer=optimizer, encoder=encoder, decoder=decoder
)

# %%
@tf.function
def train_step(inp, targ, enc_hidden):
    loss = 0

    with tf.GradientTape() as tape:
        enc_output, enc_hidden = encoder(inp, enc_hidden)
        encoder.get_layer("embedding_layer_encoder").set_weights(
            [embedding_matrix]
        )
        dec_hidden = enc_hidden

        dec_input = tf.expand_dims(
            [targ_lang.word_index["<start>"]] * BATCH_SIZE, 1
        )

        for t in range(1, targ.shape[1]):
            predictions, dec_hidden, _ = decoder(
                dec_input, dec_hidden, enc_output
            )

            loss += loss_function(targ[:, t], predictions)

            dec_input = tf.expand_dims(targ[:, t], 1)

    batch_loss = loss / int(targ.shape[1])

    variables = encoder.trainable_variables + decoder.trainable_variables

    gradients = tape.gradient(loss, variables)

    optimizer.apply_gradients(zip(gradients, variables))

    return batch_loss

# %%
EPOCHS = 100

for epoch in range(EPOCHS):
    start = time.time()

    enc_hidden = encoder.initialize_hidden_state()
    total_loss = 0

    for batch, (inp, targ) in enumerate(dataset.take(steps_per_epoch)):
        batch_loss = train_step(inp, targ, enc_hidden)
        total_loss += batch_loss

        if batch % 100 == 0:
            print(
                f"Epoch {epoch+1} Batch {batch} Loss {batch_loss.numpy():.4f}"
            )
    if (epoch + 1) % 2 == 0:
        checkpoint.save(file_prefix=checkpoint_prefix)

    print(f"Epoch {epoch+1} Loss {total_loss/steps_per_epoch:.4f}")
    print(f"Time taken for 1 epoch {time.time()-start:.2f} sec\n")
# Out:
# Epoch 1 Batch 0 Loss 6.5222
# Epoch 1 Loss 5.2688
# Time taken for 1 epoch 41.56 sec
#
# Epoch 2 Batch 0 Loss 5.3985
# Epoch 2 Loss 4.7789
# Time taken for 1 epoch 10.67 sec
#
# Epoch 3 Batch 0 Loss 4.6290
# Epoch 3 Loss 4.5858
# Time taken for 1 epoch 7.52 sec
#
# Epoch 4 Batch 0 Loss 4.3748
# Epoch 4 Loss 4.3632
# Time taken for 1 epoch 8.77 sec
#
# Epoch 5 Batch 0 Loss 4.1554
# Epoch 5 Loss 4.1030
# Time taken for 1 epoch 7.61 sec
#
# Epoch 6 Batch 0 Loss 3.9583
# Epoch 6 Loss 3.7828
# Time taken for 1 epoch 8.60 sec
#
# Epoch 7 Batch 0 Loss 3.2661
# Epoch 7 Loss 3.3910
# Time taken for 1 epoch 7.08 sec
#
# Epoch 8 Batch 0 Loss 3.0859
# Epoch 8 Loss 2.9276
# Time taken for 1 epoch 8.78 sec
#
# Epoch 9 Batch 0 Loss 2.5109
# Epoch 9 Loss 2.3943
# Time taken for 1 epoch 7.17 sec
#
# Epoch 10 Batch 0 Loss 1.9882
# Epoch 10 Loss 1.8577
# Time taken for 1 epoch 7.87 sec
#
# Epoch 11 Batch 0 Loss 1.2558
# Epoch 11 Loss 1.4060
# Time taken for 1 epoch 7.60 sec
#
# Epoch 12 Batch 0 Loss 1.0407
# Epoch 12 Loss 1.0609
# Time taken for 1 epoch 8.16 sec
#
# Epoch 13 Batch 0 Loss 0.8835
# Epoch 13 Loss 0.8043
# Time taken for 1 epoch 7.19 sec
#
# Epoch 14 Batch 0 Loss 0.4158
# Epoch 14 Loss 0.6095
# Time taken for 1 epoch 7.96 sec
#
# Epoch 15 Batch 0 Loss 0.3957
# Epoch 15 Loss 0.4578
# Time taken for 1 epoch 7.61 sec
#
# Epoch 16 Batch 0 Loss 0.3309
# Epoch 16 Loss 0.3425
# Time taken for 1 epoch 8.16 sec
#
# Epoch 17 Batch 0 Loss 0.3021
# Epoch 17 Loss 0.2587
# Time taken for 1 epoch 7.13 sec
#
# Epoch 18 Batch 0 Loss 0.2354
# Epoch 18 Loss 0.2015
# Time taken for 1 epoch 8.64 sec
#
# Epoch 19 Batch 0 Loss 0.1454
# Epoch 19 Loss 0.1569
# Time taken for 1 epoch 7.14 sec
#
# Epoch 20 Batch 0 Loss 0.1185
# Epoch 20 Loss 0.1213
# Time taken for 1 epoch 8.26 sec
#
# Epoch 21 Batch 0 Loss 0.1129
# Epoch 21 Loss 0.0953
# Time taken for 1 epoch 10.23 sec
#
# Epoch 22 Batch 0 Loss 0.1008
# Epoch 22 Loss 0.0764
# Time taken for 1 epoch 8.15 sec
#
# Epoch 23 Batch 0 Loss 0.0533
# Epoch 23 Loss 0.0628
# Time taken for 1 epoch 7.36 sec
#
# Epoch 24 Batch 0 Loss 0.0700
# Epoch 24 Loss 0.0517
# Time taken for 1 epoch 8.53 sec
#
# Epoch 25 Batch 0 Loss 0.0451
# Epoch 25 Loss 0.0439
# Time taken for 1 epoch 7.34 sec
#
# Epoch 26 Batch 0 Loss 0.0381
# Epoch 26 Loss 0.0365
# Time taken for 1 epoch 8.27 sec
#
# Epoch 27 Batch 0 Loss 0.0336
# Epoch 27 Loss 0.0326
# Time taken for 1 epoch 7.18 sec
#
# Epoch 28 Batch 0 Loss 0.0259
# Epoch 28 Loss 0.0284
# Time taken for 1 epoch 8.19 sec
#
# Epoch 29 Batch 0 Loss 0.0332
# Epoch 29 Loss 0.0270
# Time taken for 1 epoch 7.42 sec
#
# Epoch 30 Batch 0 Loss 0.0161
# Epoch 30 Loss 0.0257
# Time taken for 1 epoch 7.93 sec
#
# Epoch 31 Batch 0 Loss 0.0140
# Epoch 31 Loss 0.0228
# Time taken for 1 epoch 7.16 sec
#
# Epoch 32 Batch 0 Loss 0.0152
# Epoch 32 Loss 0.0248
# Time taken for 1 epoch 8.03 sec
#
# Epoch 33 Batch 0 Loss 0.0734
# Epoch 33 Loss 0.0250
# Time taken for 1 epoch 7.17 sec
#
# Epoch 34 Batch 0 Loss 0.0212
# Epoch 34 Loss 0.0263
# Time taken for 1 epoch 8.08 sec
#
# Epoch 35 Batch 0 Loss 0.0390
# Epoch 35 Loss 0.0275
# Time taken for 1 epoch 7.18 sec
#
# Epoch 36 Batch 0 Loss 0.0415
# Epoch 36 Loss 0.0341
# Time taken for 1 epoch 7.93 sec
#
# Epoch 37 Batch 0 Loss 0.0272
# Epoch 37 Loss 0.0421
# Time taken for 1 epoch 7.44 sec
#
# Epoch 38 Batch 0 Loss 0.0410
# Epoch 38 Loss 0.0656
# Time taken for 1 epoch 7.97 sec
#
# Epoch 39 Batch 0 Loss 0.0381
# Epoch 39 Loss 0.0776
# Time taken for 1 epoch 7.17 sec
#
# Epoch 40 Batch 0 Loss 0.1013
# Epoch 40 Loss 0.0652
# Time taken for 1 epoch 7.95 sec
#
# Epoch 41 Batch 0 Loss 0.0397
# Epoch 41 Loss 0.0562
# Time taken for 1 epoch 7.16 sec
#
# Epoch 42 Batch 0 Loss 0.0414
# Epoch 42 Loss 0.0441
# Time taken for 1 epoch 7.93 sec
#
# Epoch 43 Batch 0 Loss 0.0284
# Epoch 43 Loss 0.0378
# Time taken for 1 epoch 7.17 sec
#
# Epoch 44 Batch 0 Loss 0.0290
# Epoch 44 Loss 0.0286
# Time taken for 1 epoch 7.92 sec
#
# Epoch 45 Batch 0 Loss 0.0215
# Epoch 45 Loss 0.0209
# Time taken for 1 epoch 7.20 sec
#
# Epoch 46 Batch 0 Loss 0.0087
# Epoch 46 Loss 0.0157
# Time taken for 1 epoch 7.92 sec
#
# Epoch 47 Batch 0 Loss 0.0150
# Epoch 47 Loss 0.0126
# Time taken for 1 epoch 7.19 sec
#
# Epoch 48 Batch 0 Loss 0.0142
# Epoch 48 Loss 0.0104
# Time taken for 1 epoch 8.08 sec
#
# Epoch 49 Batch 0 Loss 0.0139
# Epoch 49 Loss 0.0088
# Time taken for 1 epoch 7.15 sec
#
# Epoch 50 Batch 0 Loss 0.0024
# Epoch 50 Loss 0.0080
# Time taken for 1 epoch 7.86 sec
#
# Epoch 51 Batch 0 Loss 0.0048
# Epoch 51 Loss 0.0065
# Time taken for 1 epoch 7.17 sec
#
# Epoch 52 Batch 0 Loss 0.0026
# Epoch 52 Loss 0.0068
# Time taken for 1 epoch 7.99 sec
#
# Epoch 53 Batch 0 Loss 0.0049
# Epoch 53 Loss 0.0064
# Time taken for 1 epoch 7.16 sec
#
# Epoch 54 Batch 0 Loss 0.0065
# Epoch 54 Loss 0.0062
# Time taken for 1 epoch 8.00 sec
#
# Epoch 55 Batch 0 Loss 0.0018
# Epoch 55 Loss 0.0068
# Time taken for 1 epoch 7.18 sec
#
# Epoch 56 Batch 0 Loss 0.0040
# Epoch 56 Loss 0.0088
# Time taken for 1 epoch 7.96 sec
#
# Epoch 57 Batch 0 Loss 0.0101
# Epoch 57 Loss 0.0101
# Time taken for 1 epoch 7.17 sec
#
# Epoch 58 Batch 0 Loss 0.0056
# Epoch 58 Loss 0.0106
# Time taken for 1 epoch 7.92 sec
#
# Epoch 59 Batch 0 Loss 0.0050
# Epoch 59 Loss 0.0112
# Time taken for 1 epoch 7.15 sec
#
# Epoch 60 Batch 0 Loss 0.0156
# Epoch 60 Loss 0.0153
# Time taken for 1 epoch 7.89 sec
#
# Epoch 61 Batch 0 Loss 0.0049
# Epoch 61 Loss 0.0214
# Time taken for 1 epoch 7.17 sec
#
# Epoch 62 Batch 0 Loss 0.0084
# Epoch 62 Loss 0.0272
# Time taken for 1 epoch 7.93 sec
#
# Epoch 63 Batch 0 Loss 0.0210
# Epoch 63 Loss 0.0548
# Time taken for 1 epoch 7.32 sec
#
# Epoch 64 Batch 0 Loss 0.0479
# Epoch 64 Loss 0.0670
# Time taken for 1 epoch 7.91 sec
#
# Epoch 65 Batch 0 Loss 0.0668
# Epoch 65 Loss 0.0706
# Time taken for 1 epoch 7.19 sec
#
# Epoch 66 Batch 0 Loss 0.0363
# Epoch 66 Loss 0.0726
# Time taken for 1 epoch 7.90 sec
#
# Epoch 67 Batch 0 Loss 0.0346
# Epoch 67 Loss 0.0570
# Time taken for 1 epoch 7.44 sec
#
# Epoch 68 Batch 0 Loss 0.0326
# Epoch 68 Loss 0.0399
# Time taken for 1 epoch 8.07 sec
#
# Epoch 69 Batch 0 Loss 0.0169
# Epoch 69 Loss 0.0287
# Time taken for 1 epoch 7.19 sec
#
# Epoch 70 Batch 0 Loss 0.0040
# Epoch 70 Loss 0.0190
# Time taken for 1 epoch 8.01 sec
#
# Epoch 71 Batch 0 Loss 0.0082
# Epoch 71 Loss 0.0150
# Time taken for 1 epoch 7.17 sec
#
# Epoch 72 Batch 0 Loss 0.0263
# Epoch 72 Loss 0.0157
# Time taken for 1 epoch 7.92 sec
#
# Epoch 73 Batch 0 Loss 0.0111
# Epoch 73 Loss 0.0158
# Time taken for 1 epoch 7.17 sec
#
# Epoch 74 Batch 0 Loss 0.0033
# Epoch 74 Loss 0.0135
# Time taken for 1 epoch 7.95 sec
#
# Epoch 75 Batch 0 Loss 0.0528
# Epoch 75 Loss 0.0097
# Time taken for 1 epoch 7.17 sec
#
# Epoch 76 Batch 0 Loss 0.0101
# Epoch 76 Loss 0.0084
# Time taken for 1 epoch 7.94 sec
#
# Epoch 77 Batch 0 Loss 0.0016
# Epoch 77 Loss 0.0074
# Time taken for 1 epoch 7.17 sec
#
# Epoch 78 Batch 0 Loss 0.0015
# Epoch 78 Loss 0.0068
# Time taken for 1 epoch 8.48 sec
#
# Epoch 79 Batch 0 Loss 0.0018
# Epoch 79 Loss 0.0056
# Time taken for 1 epoch 7.43 sec
#
# Epoch 80 Batch 0 Loss 0.0043
# Epoch 80 Loss 0.0040
# Time taken for 1 epoch 8.45 sec
#
# Epoch 81 Batch 0 Loss 0.0010
# Epoch 81 Loss 0.0046
# Time taken for 1 epoch 7.18 sec
#
# Epoch 82 Batch 0 Loss 0.0048
# Epoch 82 Loss 0.0037
# Time taken for 1 epoch 7.91 sec
#
# Epoch 83 Batch 0 Loss 0.0007
# Epoch 83 Loss 0.0040
# Time taken for 1 epoch 7.20 sec
#
# Epoch 84 Batch 0 Loss 0.0007
# Epoch 84 Loss 0.0033
# Time taken for 1 epoch 8.01 sec
#
# Epoch 85 Batch 0 Loss 0.0135
# Epoch 85 Loss 0.0033
# Time taken for 1 epoch 7.16 sec
#
# Epoch 86 Batch 0 Loss 0.0007
# Epoch 86 Loss 0.0029
# Time taken for 1 epoch 8.04 sec
#
# Epoch 87 Batch 0 Loss 0.0049
# Epoch 87 Loss 0.0027
# Time taken for 1 epoch 7.15 sec
#
# Epoch 88 Batch 0 Loss 0.0048
# Epoch 88 Loss 0.0031
# Time taken for 1 epoch 8.04 sec
#
# Epoch 89 Batch 0 Loss 0.0007
# Epoch 89 Loss 0.0033
# Time taken for 1 epoch 7.16 sec
#
# Epoch 90 Batch 0 Loss 0.0033
# Epoch 90 Loss 0.0027
# Time taken for 1 epoch 7.95 sec
#
# Epoch 91 Batch 0 Loss 0.0133
# Epoch 91 Loss 0.0029
# Time taken for 1 epoch 7.17 sec
#
# Epoch 92 Batch 0 Loss 0.0006
# Epoch 92 Loss 0.0030
# Time taken for 1 epoch 8.25 sec
#
# Epoch 93 Batch 0 Loss 0.0007
# Epoch 93 Loss 0.0040
# Time taken for 1 epoch 7.18 sec
#
# Epoch 94 Batch 0 Loss 0.0142
# Epoch 94 Loss 0.0036
# Time taken for 1 epoch 7.92 sec
#
# Epoch 95 Batch 0 Loss 0.0327
# Epoch 95 Loss 0.0062
# Time taken for 1 epoch 7.18 sec
#
# Epoch 96 Batch 0 Loss 0.0008
# Epoch 96 Loss 0.0111
# Time taken for 1 epoch 7.93 sec
#
# Epoch 97 Batch 0 Loss 0.0160
# Epoch 97 Loss 0.0155
# Time taken for 1 epoch 7.20 sec
#
# Epoch 98 Batch 0 Loss 0.0259
# Epoch 98 Loss 0.0537
# Time taken for 1 epoch 7.94 sec
#
# Epoch 99 Batch 0 Loss 0.0447
# Epoch 99 Loss 0.1171
# Time taken for 1 epoch 7.19 sec
#
# Epoch 100 Batch 0 Loss 0.1225
# Epoch 100 Loss 0.1011
# Time taken for 1 epoch 7.96 sec

# %%
def evaluate(sentence):
    attention_plot = np.zeros((max_length_targ, max_length_inp))

    sentence = preprocess(sentence)

    inputs = [inp_lang.word_index[i] for i in sentence.split(" ")]
    inputs = tf.keras.preprocessing.sequence.pad_sequences(
        [inputs], maxlen=20, padding="post"
    )
    inputs = tf.convert_to_tensor(inputs)

    result = ""

    hidden = [tf.zeros((1, units))]
    enc_out, enc_hidden = encoder(inputs, hidden)

    dec_hidden = enc_hidden
    dec_input = tf.expand_dims([targ_lang.word_index["<start>"]], 0)

    for t in range(max_length_targ):
        predictions, dec_hidden, attention_weights = decoder(
            dec_input, dec_hidden, enc_out
        )
        # storing the attention weights to plot later on
        attention_weights = tf.reshape(attention_weights, (-1,))
        attention_plot[t] = attention_weights.numpy()
        predicted_id = tf.argmax(predictions[0]).numpy()

        result += targ_lang.index_word[predicted_id] + " "

        if targ_lang.index_word[predicted_id] == "<end>":
            return result, attention_plot

        # the predicted ID is fed back into the model
        dec_input = tf.expand_dims([predicted_id], 0)

    return result, attention_plot

# %%
input_sentence = "please ensure that you use the appropriate form "
print("Input sentence in english : ", input_sentence)
predicted_output, attention_plot = evaluate(input_sentence)
print("Predicted sentence in hindi : ", predicted_output)
# Out:
# Input sentence in english :  please ensure that you use the appropriate form
# Predicted sentence in hindi :  आपकी मांग को बदलने का गाना मंजूर किया हुआ <end>

# %%
input_sentence = "and do something with it to change the world "
print("Input sentence in english : ", input_sentence)
predicted_output, attention_plot = evaluate(input_sentence)
print("Predicted sentence in hindi : ", predicted_output)
# Out:
# Input sentence in english :  and do something with it to change the world
# Predicted sentence in hindi :  और अगर मालूम हो <end>

# %% [markdown]
# # OpenInAPP sentences output

# %%
input_sentence = (
    "So even if its a big video I will clearly mention all the products "
)
print("Input sentence in english : ", input_sentence)
predicted_output, attention_plot = evaluate(input_sentence)
print("Predicted sentence in hindi : ", predicted_output)
# Out:
# Input sentence in english :  So even if its a big video I will clearly mention all the products
# Predicted sentence in hindi :  तो सच है <end>

# %%
input_sentence = "I was waiting for my bag "
print("Input sentence in english : ", input_sentence)
predicted_output, attention_plot = evaluate(input_sentence)
print("Predicted sentence in hindi : ", predicted_output)
# Out:
# Input sentence in english :  I was waiting for my bag
# Predicted sentence in hindi :  मैंने मैं धैर्य न छूट जाए। <end>

# %%
input_sentence = "definitely share your feedback in the comment section "
print("Input sentence in english : ", input_sentence)
predicted_output, attention_plot = evaluate(input_sentence)
print("Predicted sentence in hindi : ", predicted_output)
# Out:
# Input sentence in english :  definitely share your feedback in the comment section
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-66-854b97a97912> in <cell line: 3>()
#       1 input_sentence='definitely share your feedback in the comment section '
#       2 print('Input sentence in english : ',input_sentence)
# ----> 3 predicted_output,attention_plot=evaluate(input_sentence)
#       4 print('Predicted sentence in hindi : ',predicted_output)
#
# <ipython-input-61-4ac5775c6a63> in evaluate(sentence)
#       4   sentence = preprocess(sentence)
#       5
# ----> 6   inputs = [inp_lang.word_index[i] for i in sentence.split(' ')]
#       7   inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],maxlen=20, padding='post')
#       8   inputs = tf.convert_to_tensor(inputs)
#
# <ipython-input-61-4ac5775c6a63> in <listcomp>(.0)
#       4   sentence = preprocess(sentence)
#       5
# ----> 6   inputs = [inp_lang.word_index[i] for i in sentence.split(' ')]
#       7   inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],maxlen=20, padding='post')
#       8   inputs = tf.convert_to_tensor(inputs)
#
# KeyError: 'definitely'
